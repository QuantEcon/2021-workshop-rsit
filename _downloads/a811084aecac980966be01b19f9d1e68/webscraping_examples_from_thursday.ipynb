# %% [markdown]
# ## Web scraping examples
#
# https://www.statistik-bw.de/BildungKultur/SchulenAllgem/13013020.tab?R=KR116
#
# https://www.statistik-bw.de/BildungKultur/SchulenAllgem/13013020.tab?R=KR415
#
# https://www.statistik-bw.de/BildungKultur/SchulenAllgem/13013020.tab?R=KR416

# %% [markdown]
# **"Easy method"**

# %%
import pandas as pd

# %%
tables = pd.read_html("https://www.statistik-bw.de/BildungKultur/SchulenAllgem/13013020.tab?R=KR116")

# %%
len(tables)
# Out:
# 1

# %%
tables[0]
# Out:
#    SchulabgÃ¤nge aus Ã¶ffentlichen und privaten Schulen seit dem Schuljahr 1983/84 nach  Abschlussarten  Schularten  Landkreis Esslingen  \
#                                                                                                                                     Jahr
#                                                                                                                                     Jahr
#                                                                                                                                     Jahr
#                                                                                                                                     Jahr
# 0                                             1983/84
# 1                                             1984/85
# 2                                             1985/86
# 3                                             1986/87
# 4                                             1987/88
# ...

# %%
base_url = "https://www.statistik-bw.de/BildungKultur/SchulenAllgem/13013020.tab"

districts = [116, 415, 416]
output = {}
for dnum in districts:
    url = base_url + f"?R=KR{dnum}"
    print(url)

    output[dnum] = pd.read_html(url)[0]
# Out:
# https://www.statistik-bw.de/BildungKultur/SchulenAllgem/13013020.tab?R=KR116
# https://www.statistik-bw.de/BildungKultur/SchulenAllgem/13013020.tab?R=KR415
# https://www.statistik-bw.de/BildungKultur/SchulenAllgem/13013020.tab?R=KR416

# %%
output[415]
# Out:
#    SchulabgÃ¤nge aus Ã¶ffentlichen und privaten Schulen seit dem Schuljahr 1983/84 nach  Abschlussarten  Schularten  Landkreis Reutlingen  \
#                                                                                                                                      Jahr
#                                                                                                                                      Jahr
#                                                                                                                                      Jahr
#                                                                                                                                      Jahr
# 0                                             1983/84
# 1                                             1984/85
# 2                                             1985/86
# 3                                             1986/87
# 4                                             1987/88
# ...

# %% [markdown]
# **Slightly more involved**

# %%
import io
import requests

# %%
download_link = "https://www.statistik-bw.de/BildungKultur/SchulenAllgem/13013020.tab?R=KR116&form=csv"

# %%
res = requests.get(download_link)

# %% [markdown]
# _Read it into Python_

# %%
pd.read_csv?

# %%
pd.read_csv(
    io.StringIO(res.text), delimiter=";",
    header=None, skiprows=6, skipfooter=3
)
# Out:
# <ipython-input-21-327ddb44b1d4>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   pd.read_csv(
#            0    1        2      3   4        5
# 0    1983/84  478    2.452  2.951   7    1.382
# 1    1984/85  407    2.260  2.815  14    1.483
# 2    1985/86  397    2.056  2.741   9    1.382
# 3    1986/87  289    2.068  2.233  27    1.361
# 4    1987/88  377    1.784  2.217   –    1.414
# 5    1988/89  333    1.723  1.949  10    1.280
# 6    1989/90  433    1.605  1.692  15    1.193
# 7    1990/91  369    1.687  1.716  12    1.104
# 8    1991/92  355    1.586  1.649  10    1.068
# 9    1992/93  472    1.570  1.674  10    1.023
# 10   1993/94  407    1.564  1.641  19    1.056
# 11   1994/95  424    1.573  1.676  12    1.038
# 12   1995/96  468    1.561  1.751  16    1.061
# 13   1996/97  351    1.598  1.920  15    1.023
# 14   1997/98  357    1.630  1.982  12  993.000
# ...

# %% [markdown]
# _Save file to computer_

# %%
with open("test.csv", "w") as f:
    f.write(res.text)

# %% [markdown]
# **Read pdf**

# %%
import requests

# %%
res = requests.get(
    "http://www.africau.edu/images/default/sample.pdf"
)

# %%
with open("test.pdf", "wb") as f:
    f.write(res.content)

# %% [markdown]
# https://pypi.org/project/PyMuPDF/
#
# Installing camelot: https://camelot-py.readthedocs.io/en/master/user/install.html#pip

# %%
# Uncomment to install package
# !pip install PyMuPDF

# %%
import fitz

# %%
doc = fitz.open("test.pdf")

# %%
doc.get_page_text(0)
# Out:
# ' A Simple PDF File \n This is a small demonstration .pdf file - \n just for use in the Virtual Mechanics tutorials. More text. And more \n text. And more text. And more text. And more text. \n And more text. And more text. And more text. And more text. And more \n text. And more text. Boring, zzzzz. And more text. And more text. And \n more text. And more text. And more text. And more text. And more text. \n And more text. And more text. \n And more text. And more text. And more text. And more text. And more \n text. And more text. And more text. Even more. Continued on page 2 ...\n'

# %% [markdown]
# Clicking through pages and filling in boxes:
#
# https://pypi.org/project/pyppeteer/
